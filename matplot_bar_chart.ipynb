# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# Create Dataframe
my_df = pd.DataFrame(randn(25,4), columns=["Mon", "Tues", "Wed", "Thurs"])
my_df
# Out:
#          Mon      Tues       Wed     Thurs
# 0  -1.322077 -0.031837 -1.481715 -0.530445
# 1  -0.249889 -0.399409 -0.051661 -0.461378
# 2   0.431298  1.550345 -1.690679 -0.238616
# 3  -0.775712  1.108486  0.669327  1.015222
# 4   0.196151  0.311210  1.366514  0.643393
# 5  -1.719735  0.799606 -1.487242  0.288424
# 6   1.390647 -0.520253 -1.057578 -0.977802
# 7   1.361584  0.175755  0.506849  0.081882
# 8   0.217068  0.470014  0.639474  0.788959
# 9  -0.745371 -0.324460 -0.264800  0.501632
# 10 -0.022983 -0.866629 -0.110894 -0.359772
# 11  0.641961 -0.766270 -0.547697 -0.890598
# 12 -0.078206  1.793882  0.792447 -0.999044
# 13  1.247438  0.624128 -0.617459  0.206286
# 14 -0.523127  1.435799 -0.326181  1.447495
# 15  0.867438  0.437180  0.036562 -0.262703
# 16 -1.100634  1.045976 -0.762575 -0.137051
# 17 -0.797623  0.063942 -0.615642  0.493572
# 18  0.956582 -0.922873  0.644981 -0.249721
# 19 -0.744369 -0.684884 -0.153878  1.051235
# 20  0.181816 -0.303494 -0.841969  1.932961
# 21  0.561701  0.583546 -0.015139  0.463705
# 22  0.119193 -1.935453 -0.064088  0.265767
# 23  0.211332  0.203098 -0.147207  0.079096
# 24 -0.561790 -0.641795 -0.368249 -1.233034

# %%
my_df.plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
my_df.abs().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
my_df.abs().plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot: >

# %%
my_df.abs().plot.bar(stacked=True)
# Out:
# <AxesSubplot: >
