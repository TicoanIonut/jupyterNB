# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

df = pd.DataFrame(randn(100,4), columns=['Mon', 'Tues', 'Wed', 'Thur'])
df
# Out:
#          Mon      Tues       Wed      Thur
# 0   0.642668  0.441681 -1.491800 -0.412192
# 1   0.171088 -0.276212 -1.742426  0.517944
# 2  -0.505882 -1.015349 -0.205527  2.096652
# 3   1.660062 -1.758387 -0.094598 -0.598573
# 4  -0.881417 -2.211740 -0.501132 -0.880442
# ..       ...       ...       ...       ...
# 95 -1.479949  1.002309 -1.599050 -0.114854
# 96  0.498855  1.603021 -1.496829 -0.944215
# 97 -0.638546 -0.447179  0.354307 -0.418705
# 98  1.660782 -1.657985 -0.084282 -0.285731
# 99 -0.037337  0.124593  0.395591 -0.721113
#
# [100 rows x 4 columns]

# %%
df['Wed'].hist()
# Out:
# <AxesSubplot: >

# %%
df['Wed'].hist(bins=20)
# Out:
# <AxesSubplot: >

# %%
df['Wed'].plot(kind="hist", legend=True, bins=20)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df['Wed'].hist(bins=20)
