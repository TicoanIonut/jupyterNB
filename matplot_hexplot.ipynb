# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# Create Dataframe
my_df = pd.DataFrame(randn(500,4), columns=["Mon", "Tues", "Wed", "Thurs"])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0   -0.252885 -0.808515  0.084015  0.430602
# 1    1.515419  0.841338 -1.634534  0.517318
# 2    0.743341  0.293363 -2.617432 -1.236378
# 3    1.002674 -0.075003 -0.046225 -1.264685
# 4    0.577334 -0.021382  0.163544 -0.522974
# ..        ...       ...       ...       ...
# 495 -0.059842  1.859584 -0.128003  0.005202
# 496  0.312572  0.703973  1.763007 -0.064254
# 497 -1.613545 -0.119734  0.879079 -1.543161
# 498  0.939205 -0.806110 -0.087479 -0.584443
# 499 -1.007984  0.106208 -1.788541 -0.465858
#
# [500 rows x 4 columns]

# %%
my_df.abs().plot(kind="hexbin", x='Mon', y='Tues', gridsize=10)
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
my_df.plot(kind="hexbin", x='Mon', y='Tues', gridsize=10, cmap="magma")
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
my_df.plot.hexbin(x='Mon', y='Tues', C="Wed", gridsize=10)
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
my_df.abs().plot(kind="hexbin", x='Mon', y='Tues', gridsize=10, grid=True, cmap="magma")
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>
