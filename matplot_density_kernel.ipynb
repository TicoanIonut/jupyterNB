# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# Create Dataframe
my_df = pd.DataFrame(randn(500,4), columns=["Mon", "Tues", "Wed", "Thurs"])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0    0.072046 -0.870292 -1.485135  0.760420
# 1    0.467533 -0.125823 -0.724637 -0.060185
# 2   -2.860657 -0.198901  1.142777  0.247879
# 3    0.219358  0.044537 -0.845507  0.229347
# 4   -1.533065 -0.764422 -0.536456  0.157343
# ..        ...       ...       ...       ...
# 495  0.810887 -1.667976 -0.293957  1.516720
# 496  2.766685  0.993392 -0.743887  1.238335
# 497 -1.732527  1.387563  1.221053 -0.397495
# 498  0.927207  1.097726  0.181581  0.221499
# 499 -0.264778  0.410949 -1.271980  0.235347
#
# [500 rows x 4 columns]

# %%
my_df.plot(kind="kde")
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
my_df.plot.kde()
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
my_df.plot(kind="density")
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
my_df.plot.kde(alpha=0.5, lw=3)
# Out:
# <AxesSubplot: ylabel='Density'>
