# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# Create Dataframe
my_df = pd.DataFrame(randn(500,4), columns=["Mon", "Tues", "Wed", "Thurs"])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0   -0.142534 -2.075583  0.183846 -1.669494
# 1   -0.965223 -0.474999  1.021445 -1.048319
# 2    0.199571 -0.370931  0.733234 -0.915111
# 3   -1.139471  1.275123 -0.180599 -0.308745
# 4   -1.172456  1.849578 -0.825665 -1.688346
# ..        ...       ...       ...       ...
# 495  0.736015  1.505721  0.106343  1.073162
# 496 -0.430552 -0.072391 -0.709445  3.694700
# 497 -2.096561  0.616940  0.045892  1.369058
# 498 -0.126706  1.090258 -1.366710  1.347082
# 499 -1.063810 -0.422840  1.593728 -0.159680
#
# [500 rows x 4 columns]

# %%
my_df.plot(kind='box', figsize=(10, 5), cmap='jet')
# Out:
# <AxesSubplot: >

# %%
my_df.abs().plot(kind='box', figsize=(10, 5), cmap='jet')
# Out:
# <AxesSubplot: >

# %%
my_df.abs().plot(kind='box', figsize=(10, 5), cmap='jet', grid=True)
# Out:
# <AxesSubplot: >
