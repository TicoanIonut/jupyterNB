# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# Create Dataframe
my_df = pd.DataFrame(randn(500,4), columns=["Mon", "Tues", "Wed", "Thurs"])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0    1.033600 -1.716264  0.221112  1.021664
# 1   -0.312274 -0.686037 -0.041848  1.049507
# 2    0.898444  0.908960 -1.582864 -0.516311
# 3   -1.204161  1.503432  1.353447  0.903812
# 4   -2.588850  0.115425 -1.033499 -1.125415
# ..        ...       ...       ...       ...
# 495  0.437037 -1.553565  0.223828  1.699703
# 496 -1.065857 -0.094330  0.048788  0.649607
# 497  0.850535  0.459283  0.065535  0.381510
# 498 -1.494947  0.696676  0.014464 -0.976380
# 499 -0.249995  0.364663  1.126998 -0.571437
#
# [500 rows x 4 columns]

# %%
my_df.abs().plot(kind='scatter', x='Mon', y='Tues', c='Wed')
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
my_df.plot(kind='scatter', x='Mon', y='Tues', c='Wed', cmap='magma')
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
my_df.abs().plot(kind='scatter', x='Mon', y='Tues', s=my_df['Wed']*100, alpha=0.3, cmap='magma')
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>

# %%
cmap = 'magma'
colors = my_df.abs()['Wed']

# %%
my_df.abs().plot(kind='scatter', x='Mon', y='Tues', s=my_df['Wed']*100, alpha=0.3, cmap=cmap, c=colors)
# Out:
# <AxesSubplot: xlabel='Mon', ylabel='Tues'>
